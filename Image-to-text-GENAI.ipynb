# %%
import warnings, logging
warnings.simplefilter("ignore")
logging.disable(logging.WARNING)

# %%
# !pip install transformers -q

# %%
from transformers import pipeline

# %% [markdown]
# # Image captioning

# %%
caption = pipeline("image-to-text")

# %%
# TO download image in the notebook storage...
# !wget -O image2.jpg 'https://cdn.pixabay.com/photo/2023/12/08/19/39/ai-generated-8438023_1280.jpg'

# %%
from IPython.display import Image
image_name = "1646204735721.jpg"
# image_name = ai-generated-8438023_1280.jpeg"
Image(filename = image_name)

# %%
caption(image_name)
